# %%
import json
import matplotlib.pyplot as plt
import viz
# %config InlineBackend.figure_formats = ['svg']

colors, swatches = viz.phd_style(jupyterStyle = True)

# %%
with open("./ent_data_ch36_58.json", 'r') as file:
    data = json.load(file)

# %%
data.keys()
# Out:
# dict_keys(['hist_data', 'hist_data_index', 'count_data', 'save_time', 'inside_histogram'])

# %%
fig, ax = plt.subplots(figsize = (7,5))

ax.plot(data["hist_data_index"], data["hist_data"])
ax.set_xlabel("time (ps)")
ax.set_ylabel("counts")
ax.grid()
